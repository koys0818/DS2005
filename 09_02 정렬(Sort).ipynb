# %% [markdown]
# # 정렬 (Sort)
# ---
#
# ![sort](https://docs.tibco.com/pub/sfire-bauthor/7.5.0/doc/html/ko-KR/GUID-38D24175-9A0A-4A2B-A603-FC02F72AA8DB-display.png)
#
# - `어떤 기준`에 의해 값을 정렬
#     - ex: `오름차순` 기준이라면 값이 작은게 우선순위가 높고, 큰게 뒤로 간다
#     - ex: `내림차순` 기준이라면 값이 큰게 우선순위가 높고, 큰게 뒤로 간다

# %% [markdown]
# ---
# ## sort(), sorted()
# - sort() : 원본 변경
# - sorted() : 대상 변경 없이, 정렬된 결과 리턴
#
# ※위 정렬 함수는 `Timsort` 라는 정렬 알고리즘 사용

# %%
import random
myList = [
    random.randrange(1, 1000)
    for i in range(1000)
]

# myList

# %%
myList.sort()  # myList 원본을 변화시켰다!

# %%
myList[0:20]
# Out:
# [2, 2, 5, 6, 8, 9, 13, 14, 15, 15, 16, 17, 17, 17, 18, 18, 18, 18, 19, 21]

# %%
random.shuffle(myList)
myList[0:20]
# Out:
# [770,
#  425,
#  247,
#  966,
#  943,
#  846,
#  179,
#  372,
#  499,
#  146,
#  526,
#  727,
#  265,
#  501,
#  727,
#  238,
#  87,
#  822,
#  945,
#  662]

# %%
sorted(myList)   # 정렬된 '결과'를 리턴 ,  myList 원본은 변화 안시킴
# Out:
# [2,
#  2,
#  5,
#  6,
#  8,
#  9,
#  13,
#  14,
#  15,
#  15,
#  16,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  18,
#  19,
#  21,
#  21,
#  27,
#  28,
#  29,
#  30,
#  31,
#  32,
#  33,
#  34,
#  35,
#  40,
#  40,
#  40,
#  41,
#  43,
#  44,
#  46,
#  46,
#  48,
#  48,
#  49,
#  49,
#  50,
#  50,
#  51,
#  53,
#  53,
#  54,
#  56,
#  59,
#  59,
#  60,
#  61,
#  63,
#  63,
#  65,
#  67,
#  67,
#  67,
#  68,
#  68,
#  69,
#  70,
#  73,
#  75,
#  77,
#  78,
#  79,
#  80,
#  80,
#  80,
#  81,
#  82,
#  83,
#  84,
#  86,
#  87,
#  89,
#  90,
#  92,
#  94,
#  94,
#  94,
#  95,
#  95,
#  97,
#  100,
#  103,
#  104,
#  104,
#  104,
#  104,
#  106,
#  107,
#  107,
#  107,
#  109,
#  109,
#  110,
#  110,
#  110,
#  112,
#  114,
#  114,
#  117,
#  117,
#  118,
#  118,
#  118,
#  118,
#  119,
#  120,
#  120,
#  121,
#  121,
#  124,
#  124,
#  125,
#  125,
#  127,
#  128,
#  131,
#  132,
#  134,
#  134,
#  135,
#  135,
#  135,
#  136,
#  138,
#  139,
#  140,
#  140,
#  141,
#  141,
#  142,
#  142,
#  144,
#  145,
#  146,
#  147,
#  147,
#  147,
#  149,
#  149,
#  151,
#  154,
#  154,
#  154,
#  154,
#  156,
#  156,
#  156,
#  156,
#  156,
#  161,
#  165,
#  166,
#  166,
#  166,
#  167,
#  168,
#  168,
#  170,
#  171,
#  171,
#  171,
#  172,
#  172,
#  173,
#  173,
#  176,
#  177,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  184,
#  185,
#  185,
#  185,
#  186,
#  187,
#  189,
#  189,
#  189,
#  190,
#  192,
#  193,
#  193,
#  194,
#  195,
#  196,
#  196,
#  197,
#  200,
#  202,
#  203,
#  203,
#  204,
#  205,
#  207,
#  209,
#  212,
#  213,
#  213,
#  213,
#  215,
#  215,
#  215,
#  215,
#  218,
#  218,
#  221,
#  224,
#  225,
#  227,
#  228,
#  229,
#  232,
#  232,
#  233,
#  233,
#  233,
#  234,
#  235,
#  235,
#  236,
#  236,
#  238,
#  239,
#  239,
#  240,
#  242,
#  243,
#  243,
#  243,
#  244,
#  244,
#  246,
#  247,
#  247,
#  248,
#  248,
#  248,
#  250,
#  251,
#  252,
#  252,
#  252,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  259,
#  259,
#  259,
#  259,
#  259,
#  261,
#  262,
#  262,
#  262,
#  263,
#  264,
#  265,
#  265,
#  265,
#  265,
#  267,
#  267,
#  267,
#  268,
#  268,
#  273,
#  274,
#  276,
#  278,
#  278,
#  278,
#  279,
#  279,
#  280,
#  281,
#  282,
#  284,
#  284,
#  285,
#  289,
#  289,
#  290,
#  293,
#  295,
#  296,
#  296,
#  297,
#  299,
#  300,
#  300,
#  301,
#  301,
#  302,
#  305,
#  306,
#  307,
#  307,
#  307,
#  308,
#  310,
#  310,
#  311,
#  312,
#  313,
#  313,
#  315,
#  315,
#  315,
#  316,
#  316,
#  317,
#  320,
#  321,
#  321,
#  321,
#  323,
#  324,
#  325,
#  325,
#  328,
#  331,
#  331,
#  332,
#  332,
#  332,
#  333,
#  333,
#  334,
#  336,
#  336,
#  338,
#  340,
#  341,
#  341,
#  342,
#  343,
#  343,
#  344,
#  346,
#  347,
#  349,
#  349,
#  351,
#  351,
#  353,
#  354,
#  354,
#  356,
#  357,
#  358,
#  358,
#  358,
#  359,
#  361,
#  361,
#  361,
#  361,
#  365,
#  366,
#  370,
#  370,
#  371,
#  372,
#  375,
#  376,
#  378,
#  379,
#  380,
#  383,
#  384,
#  385,
#  386,
#  386,
#  390,
#  391,
#  392,
#  394,
#  394,
#  398,
#  399,
#  400,
#  400,
#  401,
#  402,
#  402,
#  404,
#  405,
#  406,
#  406,
#  407,
#  409,
#  409,
#  410,
#  412,
#  412,
#  413,
#  413,
#  414,
#  414,
#  415,
#  417,
#  418,
#  418,
#  419,
#  420,
#  421,
#  421,
#  422,
#  422,
#  423,
#  423,
#  425,
#  425,
#  425,
#  427,
#  428,
#  428,
#  429,
#  431,
#  434,
#  434,
#  437,
#  437,
#  437,
#  437,
#  438,
#  441,
#  443,
#  444,
#  446,
#  446,
#  447,
#  448,
#  448,
#  448,
#  448,
#  450,
#  450,
#  451,
#  451,
#  452,
#  452,
#  453,
#  454,
#  455,
#  455,
#  456,
#  456,
#  458,
#  460,
#  461,
#  461,
#  462,
#  463,
#  465,
#  467,
#  470,
#  471,
#  471,
#  472,
#  472,
#  473,
#  474,
#  474,
#  477,
#  478,
#  483,
#  486,
#  487,
#  488,
#  488,
#  490,
#  490,
#  491,
#  493,
#  495,
#  496,
#  496,
#  499,
#  501,
#  502,
#  503,
#  504,
#  504,
#  505,
#  505,
#  505,
#  507,
#  509,
#  510,
#  512,
#  512,
#  513,
#  514,
#  516,
#  516,
#  522,
#  523,
#  524,
#  526,
#  526,
#  526,
#  529,
#  529,
#  529,
#  529,
#  531,
#  532,
#  534,
#  535,
#  536,
#  536,
#  536,
#  537,
#  537,
#  538,
#  539,
#  539,
#  540,
#  540,
#  542,
#  543,
#  543,
#  545,
#  545,
#  545,
#  547,
#  548,
#  550,
#  552,
#  553,
#  554,
#  555,
#  556,
#  556,
#  556,
#  557,
#  558,
#  559,
#  559,
#  559,
#  561,
#  561,
#  563,
#  564,
#  564,
#  564,
#  565,
#  566,
#  568,
#  569,
#  570,
#  571,
#  571,
#  573,
#  573,
#  574,
#  574,
#  577,
#  577,
#  577,
#  577,
#  582,
#  583,
#  585,
#  585,
#  586,
#  587,
#  587,
#  588,
#  589,
#  590,
#  590,
#  590,
#  591,
#  592,
#  592,
#  594,
#  594,
#  596,
#  596,
#  596,
#  597,
#  597,
#  597,
#  597,
#  598,
#  599,
#  599,
#  600,
#  603,
#  605,
#  606,
#  606,
#  608,
#  608,
#  608,
#  608,
#  609,
#  610,
#  612,
#  615,
#  616,
#  619,
#  619,
#  622,
#  622,
#  624,
#  625,
#  625,
#  628,
#  630,
#  631,
#  631,
#  631,
#  632,
#  632,
#  633,
#  633,
#  634,
#  643,
#  643,
#  644,
#  646,
#  646,
#  646,
#  646,
#  647,
#  647,
#  649,
#  651,
#  652,
#  656,
#  656,
#  658,
#  658,
#  659,
#  659,
#  662,
#  663,
#  664,
#  666,
#  669,
#  672,
#  674,
#  674,
#  674,
#  675,
#  675,
#  676,
#  679,
#  680,
#  681,
#  683,
#  684,
#  684,
#  685,
#  685,
#  686,
#  686,
#  687,
#  689,
#  691,
#  691,
#  694,
#  695,
#  696,
#  698,
#  701,
#  702,
#  702,
#  704,
#  704,
#  704,
#  704,
#  706,
#  706,
#  709,
#  711,
#  711,
#  711,
#  712,
#  713,
#  714,
#  714,
#  715,
#  715,
#  716,
#  717,
#  717,
#  718,
#  719,
#  719,
#  719,
#  720,
#  720,
#  722,
#  723,
#  723,
#  723,
#  724,
#  724,
#  727,
#  727,
#  727,
#  730,
#  730,
#  730,
#  732,
#  732,
#  733,
#  733,
#  733,
#  735,
#  738,
#  738,
#  739,
#  740,
#  743,
#  744,
#  744,
#  745,
#  745,
#  747,
#  747,
#  748,
#  749,
#  752,
#  754,
#  754,
#  756,
#  756,
#  758,
#  759,
#  759,
#  760,
#  760,
#  761,
#  761,
#  761,
#  762,
#  763,
#  768,
#  768,
#  770,
#  770,
#  773,
#  773,
#  774,
#  775,
#  776,
#  776,
#  776,
#  777,
#  779,
#  780,
#  781,
#  781,
#  784,
#  785,
#  785,
#  787,
#  788,
#  788,
#  789,
#  789,
#  790,
#  790,
#  791,
#  792,
#  792,
#  794,
#  795,
#  797,
#  797,
#  799,
#  799,
#  800,
#  801,
#  801,
#  804,
#  805,
#  806,
#  806,
#  806,
#  807,
#  807,
#  808,
#  809,
#  810,
#  811,
#  812,
#  812,
#  813,
#  814,
#  816,
#  819,
#  819,
#  821,
#  821,
#  822,
#  822,
#  822,
#  823,
#  825,
#  827,
#  829,
#  829,
#  829,
#  830,
#  832,
#  835,
#  835,
#  837,
#  837,
#  838,
#  839,
#  840,
#  842,
#  843,
#  845,
#  845,
#  846,
#  846,
#  848,
#  851,
#  852,
#  853,
#  854,
#  854,
#  855,
#  855,
#  855,
#  855,
#  856,
#  857,
#  858,
#  859,
#  859,
#  860,
#  861,
#  861,
#  862,
#  862,
#  862,
#  862,
#  863,
#  864,
#  866,
#  867,
#  870,
#  870,
#  873,
#  874,
#  876,
#  877,
#  877,
#  879,
#  879,
#  879,
#  881,
#  881,
#  882,
#  882,
#  883,
#  883,
#  883,
#  885,
#  885,
#  885,
#  887,
#  890,
#  891,
#  892,
#  893,
#  894,
#  894,
#  895,
#  897,
#  898,
#  904,
#  905,
#  906,
#  907,
#  908,
#  908,
#  909,
#  910,
#  912,
#  913,
#  913,
#  913,
#  914,
#  915,
#  915,
#  915,
#  917,
#  918,
#  918,
#  919,
#  919,
#  922,
#  922,
#  922,
#  928,
#  930,
#  930,
#  930,
#  931,
#  931,
#  932,
#  933,
#  934,
#  935,
#  936,
#  936,
#  936,
#  937,
#  940,
#  940,
#  941,
#  941,
#  942,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  947,
#  947,
#  948,
#  948,
#  948,
#  951,
#  951,
#  952,
#  953,
#  953,
#  953,
#  954,
#  956,
#  956,
#  957,
#  957,
#  957,
#  959,
#  960,
#  960,
#  960,
#  961,
#  961,
#  962,
#  966,
#  967,
#  968,
#  968,
#  968,
#  970,
#  971,
#  972,
#  973,
#  975,
#  975,
#  977,
#  977,
#  978,
#  978,
#  980,
#  981,
#  981,
#  981,
#  984,
#  984,
#  985,
#  986,
#  986,
#  986,
#  987,
#  987,
#  987,
#  988,
#  990,
#  992,
#  997]

# %%
myList[0:20]
# Out:
# [770,
#  425,
#  247,
#  966,
#  943,
#  846,
#  179,
#  372,
#  499,
#  146,
#  526,
#  727,
#  265,
#  501,
#  727,
#  238,
#  87,
#  822,
#  945,
#  662]

# %% [markdown]
# # 정렬 알고리즘의 성능
# time complexity 는 다음 3가지로 귀결
#
# 1. **O(*n*<sup>2</sup>)**  <-- worst
# 1. **O(*n* log *n*)**    <-- average
# 1. **O(*n*)**          <-- impossible?
#
# > 특정 정렬 알고리즘의 성능이 항상 고정되어 있지 않다.   정렬하는 데이터의 분포 나 형태에 따라 성능이 달라질수 있다.     따라서,  각 알고리즘을 정확히 이해하고, 구현할줄 알며, 각각의 특성에 따라 어떠한 데이터 상황에서 정렬에 유리한지 알아야 한다.

# %% [markdown]
# # 다양한 정렬 알고리즘
#
# https://www.toptal.com/developers/sorting-algorithms  (시각화, 비교)
#
# ![sort](http://www.webappers.com/img/2009/04/sorting-algorithm.jpg)
#
#
# # 알고리즘 시각화 사이트
#
# https://visualgo.net/ko
#
# http://sorting.at/#

# %% [markdown]
# # 정렬및 검색 알고리즘 학습시..
#
# - 각 알고리즘에 대한 이해
# - 각 동작 사이클마다 값의 변화 (ex: 정렬상태의 변화)
# - 각 알고리즘의 성능에 대한 이해
#     - **best case** VS **worst case**
